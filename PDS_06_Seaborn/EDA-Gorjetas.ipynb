# %%
import pandas as pd
dados = pd.read_csv('tips.csv')

# %%
dados.head()
# Out:
#    total_bill   tip dessert  day    time  size
# 0       16.99  1.01      No  Sun  Dinner     2
# 1       10.34  1.66      No  Sun  Dinner     3
# 2       21.01  3.50      No  Sun  Dinner     3
# 3       23.68  3.31      No  Sun  Dinner     2
# 4       24.59  3.61      No  Sun  Dinner     4

# %%
dados.columns
# Out:
# Index(['total_bill', 'tip', 'dessert', 'day', 'time', 'size'], dtype='object')

# %%
renomear = {
    'total_bill' : 'valor_conta',
    'tip' : 'gorjeta', 
    'dessert' : 'sobremesa', 
    'day': 'dia', 
    'time': 'refeição', 
    'size' : 'total_pessoas'  
}

# %%
gorjetas = dados.rename(columns = renomear)

# %%
gorjetas
# Out:
#      valor_conta  gorjeta sobremesa   dia refeição  total_pessoas
# 0          16.99     1.01        No   Sun   Dinner              2
# 1          10.34     1.66        No   Sun   Dinner              3
# 2          21.01     3.50        No   Sun   Dinner              3
# 3          23.68     3.31        No   Sun   Dinner              2
# 4          24.59     3.61        No   Sun   Dinner              4
# ..           ...      ...       ...   ...      ...            ...
# 239        29.03     5.92        No   Sat   Dinner              3
# 240        27.18     2.00       Yes   Sat   Dinner              2
# 241        22.67     2.00       Yes   Sat   Dinner              2
# 242        17.82     1.75        No   Sat   Dinner              2
# 243        18.78     3.00        No  Thur   Dinner              2
#
# [244 rows x 6 columns]

# %%
gorjetas.sobremesa.unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
sim_nao = {
    'No': 'Não', 
    'Yes': 'Sim'
}

# %%
gorjetas.sobremesa = gorjetas.sobremesa.map(sim_nao)

# %%
gorjetas
# Out:
#      valor_conta  gorjeta sobremesa   dia refeição  total_pessoas
# 0          16.99     1.01       Não   Sun   Dinner              2
# 1          10.34     1.66       Não   Sun   Dinner              3
# 2          21.01     3.50       Não   Sun   Dinner              3
# 3          23.68     3.31       Não   Sun   Dinner              2
# 4          24.59     3.61       Não   Sun   Dinner              4
# ..           ...      ...       ...   ...      ...            ...
# 239        29.03     5.92       Não   Sat   Dinner              3
# 240        27.18     2.00       Sim   Sat   Dinner              2
# 241        22.67     2.00       Sim   Sat   Dinner              2
# 242        17.82     1.75       Não   Sat   Dinner              2
# 243        18.78     3.00       Não  Thur   Dinner              2
#
# [244 rows x 6 columns]

# %%
gorjetas.dia.unique()
# Out:
# array(['Sun', 'Sat', 'Thur', 'Fri'], dtype=object)

# %%
semana = {
    'Sun' : 'Dom', 
    'Sat': 'Sáb', 
    'Thur': 'Qui',
    'Fri': 'Sex'
}

# %%
gorjetas.dia = gorjetas.dia.map(semana)

# %%
refeicao = {
    'Dinner': 'Jantar', 
    'Lunch': 'Almoço'
}

# %%
gorjetas['refeição'] = gorjetas['refeição'].map(refeicao)

# %%
gorjetas
# Out:
#      valor_conta  gorjeta sobremesa  dia refeição  total_pessoas
# 0          16.99     1.01       Não  Dom   Jantar              2
# 1          10.34     1.66       Não  Dom   Jantar              3
# 2          21.01     3.50       Não  Dom   Jantar              3
# 3          23.68     3.31       Não  Dom   Jantar              2
# 4          24.59     3.61       Não  Dom   Jantar              4
# ..           ...      ...       ...  ...      ...            ...
# 239        29.03     5.92       Não  Sáb   Jantar              3
# 240        27.18     2.00       Sim  Sáb   Jantar              2
# 241        22.67     2.00       Sim  Sáb   Jantar              2
# 242        17.82     1.75       Não  Sáb   Jantar              2
# 243        18.78     3.00       Não  Qui   Jantar              2
#
# [244 rows x 6 columns]

# %%
gorjetas.tail(10)
# Out:
#      valor_conta  gorjeta sobremesa  dia refeição  total_pessoas
# 234        15.53     3.00       Sim  Sáb   Jantar              2
# 235        10.07     1.25       Não  Sáb   Jantar              2
# 236        12.60     1.00       Sim  Sáb   Jantar              2
# 237        32.83     1.17       Sim  Sáb   Jantar              2
# 238        35.83     4.67       Não  Sáb   Jantar              3
# 239        29.03     5.92       Não  Sáb   Jantar              3
# 240        27.18     2.00       Sim  Sáb   Jantar              2
# 241        22.67     2.00       Sim  Sáb   Jantar              2
# 242        17.82     1.75       Não  Sáb   Jantar              2
# 243        18.78     3.00       Não  Qui   Jantar              2

# %%
gorjetas['de 0 a'] = range(gorjetas.shape[0]) #criando uma coluna

# %%
gorjetas
# Out:
#      valor_conta  gorjeta sobremesa  dia refeição  total_pessoas  de 0 a
# 0          16.99     1.01       Não  Dom   Jantar              2       0
# 1          10.34     1.66       Não  Dom   Jantar              3       1
# 2          21.01     3.50       Não  Dom   Jantar              3       2
# 3          23.68     3.31       Não  Dom   Jantar              2       3
# 4          24.59     3.61       Não  Dom   Jantar              4       4
# ..           ...      ...       ...  ...      ...            ...     ...
# 239        29.03     5.92       Não  Sáb   Jantar              3     239
# 240        27.18     2.00       Sim  Sáb   Jantar              2     240
# 241        22.67     2.00       Sim  Sáb   Jantar              2     241
# 242        17.82     1.75       Não  Sáb   Jantar              2     242
# 243        18.78     3.00       Não  Qui   Jantar              2     243
#
# [244 rows x 7 columns]

# %%
gorjetas.drop('de 0 a', axis=1) #removendo uma coluna
# Out:
#      valor_conta  gorjeta sobremesa  dia refeição  total_pessoas
# 0          16.99     1.01       Não  Dom   Jantar              2
# 1          10.34     1.66       Não  Dom   Jantar              3
# 2          21.01     3.50       Não  Dom   Jantar              3
# 3          23.68     3.31       Não  Dom   Jantar              2
# 4          24.59     3.61       Não  Dom   Jantar              4
# ..           ...      ...       ...  ...      ...            ...
# 239        29.03     5.92       Não  Sáb   Jantar              3
# 240        27.18     2.00       Sim  Sáb   Jantar              2
# 241        22.67     2.00       Sim  Sáb   Jantar              2
# 242        17.82     1.75       Não  Sáb   Jantar              2
# 243        18.78     3.00       Não  Qui   Jantar              2
#
# [244 rows x 6 columns]

# %%
# !pip install seaborn==0.9.0

# %%
import seaborn as sns

# %%
# !pip show seaborn
# Out:
# Name: seaborn
# Version: 0.9.0
# Summary: seaborn: statistical data visualization
# Home-page: https://seaborn.pydata.org
# Author: Michael Waskom
# Author-email: mwaskom@nyu.edu
# License: BSD (3-clause)
# Location: c:\users\intel\anaconda3\lib\site-packages
# Requires: pandas, matplotlib, scipy, numpy
# Required-by:

# %% [markdown]
# ## Análise I - Valor da Conta e Gorjeta

# %%
gorjetas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   valor_conta    244 non-null    float64
#  1   gorjeta        244 non-null    float64
#  2   sobremesa      244 non-null    object
#  3   dia            244 non-null    object
#  4   refeição       244 non-null    object
#  5   total_pessoas  244 non-null    int64
#  6   de 0 a         244 non-null    int64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 13.5+ KB

# %%
valor_gorjeta  = sns.scatterplot(x = 'valor_conta', y = 'gorjeta', data = gorjetas)

# %% [markdown]
# ###### Visualmente o valor da gorjeta aumenta conforme o valor da conta

# %%
print(f'Temos {gorjetas.shape[0]} observações.')
# Out:
# Temos 244 observações.

# %%
gorjetas.isnull()
# Out:
#      valor_conta  gorjeta  sobremesa    dia  refeição  total_pessoas  de 0 a
# 0          False    False      False  False     False          False   False
# 1          False    False      False  False     False          False   False
# 2          False    False      False  False     False          False   False
# 3          False    False      False  False     False          False   False
# 4          False    False      False  False     False          False   False
# ..           ...      ...        ...    ...       ...            ...     ...
# 239        False    False      False  False     False          False   False
# 240        False    False      False  False     False          False   False
# 241        False    False      False  False     False          False   False
# 242        False    False      False  False     False          False   False
# 243        False    False      False  False     False          False   False
#
# [244 rows x 7 columns]

# %%
gorjetas.count()
# Out:
# valor_conta      244
# gorjeta          244
# sobremesa        244
# dia              244
# refeição         244
# total_pessoas    244
# de 0 a           244
# dtype: int64

# %% [markdown]
# ##### Criando o campo porcentagem

# %%
gorjetas.drop(['de 0 a'], axis=1)
# Out:
#      valor_conta  gorjeta sobremesa  dia refeição  total_pessoas
# 0          16.99     1.01       Não  Dom   Jantar              2
# 1          10.34     1.66       Não  Dom   Jantar              3
# 2          21.01     3.50       Não  Dom   Jantar              3
# 3          23.68     3.31       Não  Dom   Jantar              2
# 4          24.59     3.61       Não  Dom   Jantar              4
# ..           ...      ...       ...  ...      ...            ...
# 239        29.03     5.92       Não  Sáb   Jantar              3
# 240        27.18     2.00       Sim  Sáb   Jantar              2
# 241        22.67     2.00       Sim  Sáb   Jantar              2
# 242        17.82     1.75       Não  Sáb   Jantar              2
# 243        18.78     3.00       Não  Qui   Jantar              2
#
# [244 rows x 6 columns]

# %%
gorjetas['porcentagem'] = (gorjetas.gorjeta / gorjetas.valor_conta) * 100

# %%
gorjetas
# Out:
#      valor_conta  gorjeta sobremesa  dia refeição  total_pessoas  de 0 a  \
# 0          16.99     1.01       Não  Dom   Jantar              2       0
# 1          10.34     1.66       Não  Dom   Jantar              3       1
# 2          21.01     3.50       Não  Dom   Jantar              3       2
# 3          23.68     3.31       Não  Dom   Jantar              2       3
# 4          24.59     3.61       Não  Dom   Jantar              4       4
# ..           ...      ...       ...  ...      ...            ...     ...
# 239        29.03     5.92       Não  Sáb   Jantar              3     239
# 240        27.18     2.00       Sim  Sáb   Jantar              2     240
# 241        22.67     2.00       Sim  Sáb   Jantar              2     241
# 242        17.82     1.75       Não  Sáb   Jantar              2     242
# 243        18.78     3.00       Não  Qui   Jantar              2     243
#
#      porcentagem
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# ...

# %%
gorjetas.porcentagem = gorjetas.porcentagem.round(2)

# %%
gorjetas
# Out:
#      valor_conta  gorjeta sobremesa  dia refeição  total_pessoas  de 0 a  \
# 0          16.99     1.01       Não  Dom   Jantar              2       0
# 1          10.34     1.66       Não  Dom   Jantar              3       1
# 2          21.01     3.50       Não  Dom   Jantar              3       2
# 3          23.68     3.31       Não  Dom   Jantar              2       3
# 4          24.59     3.61       Não  Dom   Jantar              4       4
# ..           ...      ...       ...  ...      ...            ...     ...
# 239        29.03     5.92       Não  Sáb   Jantar              3     239
# 240        27.18     2.00       Sim  Sáb   Jantar              2     240
# 241        22.67     2.00       Sim  Sáb   Jantar              2     241
# 242        17.82     1.75       Não  Sáb   Jantar              2     242
# 243        18.78     3.00       Não  Qui   Jantar              2     243
#
#      porcentagem
# 0           5.94
# 1          16.05
# 2          16.66
# 3          13.98
# ...

# %%
porc_conta = sns.scatterplot(x = 'valor_conta', y = 'porcentagem', data = gorjetas)

# %% [markdown]
# ### o valor da gorjeta cai, proporcionalmente, com o aumento do valor da conta

# %%
porc_conta_linha = sns.relplot(x = 'valor_conta', y = 'porcentagem', kind = 'line', data = gorjetas)

# %%
sns.lmplot(x='valor_conta', y = 'porcentagem', data = gorjetas )
